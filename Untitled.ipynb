# %%
# !pip3 install pandas tensorflow
# Out:
# ...
#      |████████████████████████████████| 9.3 MB 3.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 320.5 MB 4.8 kB/s eta 0:00:015   |██████▋                         | 66.4 MB 1.1 MB/s eta 0:04:02     |█████████████████▌              | 175.5 MB 1.6 MB/s eta 0:01:29
# ...
#      |████████████████████████████████| 509 kB 586 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.5 MB 122 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 173 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 175 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 1.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 1.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.6 MB 1.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 127 kB 3.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 459 kB 3.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8 MB 606 kB/s eta 0:00:01
# ...

# %%
# !pip3 list
# Out:
# Package                Version
# ---------------------- --------------------
# absl-py                0.11.0
# appdirs                1.4.4
# argon2-cffi            20.1.0
# astunparse             1.6.3
# async-generator        1.10
# attrs                  19.3.0
# Automat                0.8.0
# backcall               0.2.0
# bleach                 3.2.1
# blinker                1.4
# cachetools             4.1.1
# certifi                2019.11.28
# cffi                   1.14.4
# chardet                3.0.4
# Click                  7.0
# cloud-init             20.2
# colorama               0.4.3
# command-not-found      0.3
# configobj              5.0.6
# constantly             15.1.0
# cryptography           2.8
# dbus-python            1.2.16
# decorator              4.4.2
# defusedxml             0.6.0
# distlib                0.3.1
# distro                 1.4.0
# distro-info            0.23ubuntu1
# entrypoints            0.3
# filelock               3.0.12
# ...
